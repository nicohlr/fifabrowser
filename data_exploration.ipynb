# %% [markdown]
# # **Data exploration**

# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv')
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
a = df[['Name', 'Flag']].to_dict('records')

# %%
b = list()
b += [x['Name'], x['Nationality']] for x in a
b
# Out:
#   File "<ipython-input-4-f235502a6404>", line 2
#     b += [x['Name'], x['Nationality']] for x in a
#                                          ^
# SyntaxError: invalid syntax

# %%
for x in a[:10]:
    print(list(x.values()))
# Out:
# ['L. Messi', 'https://cdn.sofifa.org/flags/52.png']
# ['Cristiano Ronaldo', 'https://cdn.sofifa.org/flags/38.png']
# ['Neymar Jr', 'https://cdn.sofifa.org/flags/54.png']
# ['De Gea', 'https://cdn.sofifa.org/flags/45.png']
# ['K. De Bruyne', 'https://cdn.sofifa.org/flags/7.png']
# ['E. Hazard', 'https://cdn.sofifa.org/flags/7.png']
# ['L. Modrić', 'https://cdn.sofifa.org/flags/10.png']
# ['L. Suárez', 'https://cdn.sofifa.org/flags/60.png']
# ['Sergio Ramos', 'https://cdn.sofifa.org/flags/45.png']
# ['J. Oblak', 'https://cdn.sofifa.org/flags/44.png']

# %%
[list(x.values()) for x in a]
# Out:
# [['L. Messi', 'https://cdn.sofifa.org/flags/52.png'],
#  ['Cristiano Ronaldo', 'https://cdn.sofifa.org/flags/38.png'],
#  ['Neymar Jr', 'https://cdn.sofifa.org/flags/54.png'],
#  ['De Gea', 'https://cdn.sofifa.org/flags/45.png'],
#  ['K. De Bruyne', 'https://cdn.sofifa.org/flags/7.png'],
#  ['E. Hazard', 'https://cdn.sofifa.org/flags/7.png'],
#  ['L. Modrić', 'https://cdn.sofifa.org/flags/10.png'],
#  ['L. Suárez', 'https://cdn.sofifa.org/flags/60.png'],
#  ['Sergio Ramos', 'https://cdn.sofifa.org/flags/45.png'],
#  ['J. Oblak', 'https://cdn.sofifa.org/flags/44.png'],
#  ['R. Lewandowski', 'https://cdn.sofifa.org/flags/37.png'],
#  ['T. Kroos', 'https://cdn.sofifa.org/flags/21.png'],
#  ['D. Godín', 'https://cdn.sofifa.org/flags/60.png'],
#  ['David Silva', 'https://cdn.sofifa.org/flags/45.png'],
#  ['N. Kanté', 'https://cdn.sofifa.org/flags/18.png'],
#  ['P. Dybala', 'https://cdn.sofifa.org/flags/52.png'],
#  ['H. Kane', 'https://cdn.sofifa.org/flags/14.png'],
# ...
